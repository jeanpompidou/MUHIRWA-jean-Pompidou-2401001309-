# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanpompidou/MUHIRWA-jean-Pompidou-2401001309-/blob/main/MUHIRWA_Jean_Pompidou_2401001309.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import request

# %%
import requests
import json
# !pip3 install requests

# %%
response = requests.get('https://api.stackexchange.com/docs/questions')
print(response.text)
# print(response.json())
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta http-equiv="cleartype" content="on">
#     <title>
# Usage of /questions [GET] -
#         Stack Exchange API
#     </title>
#     <link rel="stylesheet" href="https://cdn.sstatic.net/apiv2/all.css?v=f833d2551d9b">
#         <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.7.1/jquery.min.js"></script>
#
#     <script src="https://cdn.sstatic.net/apiv2/js/jquery-ui-1.13.2.custom.min.js?v=18d3052969c0"></script>
#     <script src="https://cdn.sstatic.net/apiv2/js/console.js?v=b82c66decfe0"></script>
#     <script src="https://cdn.sstatic.net/apiv2/js/highlight.js?v=15120a2077b5"></script>
#
#
#
#     <script>
# ...

# %% [markdown]
# # New Section
